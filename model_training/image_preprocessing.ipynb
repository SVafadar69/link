# %%
import os 
from pathlib import Path 
import random 
import shutil

image_folder = os.path.join(os.getcwd(), 'package_images')

def download_filtered_images_locally(image_paths: list[str], output_dir: str) -> None: 
    output = Path(output_dir)
    output.mkdir(parents=True, exist_ok=True)

    for image_path in image_paths: 
        src = Path(image_path)
        if src.exists():
            dest = output / src.name 
            shutil.copy2(src, dest)
            print(f'Downloaded: {src.name}')
        else: 
            print(f'Skipped {image_path}')


def combine_images(base_dir: str, sample_size: int = 1000) -> list[str]: 
    base = Path(base_dir)
    image_extensions = {'.jpg', '.jpeg', '.png', '.tiff', '.webp'}
    splits = {'train', 'test', 'valid'}
    filtered_images = []

    for split in splits: 
        images_dir = base  / split / 'images'
        if images_dir.exists():
            for file in sorted(images_dir.iterdir()):
                if file.suffix.lower() in image_extensions: 
                    filtered_images.append(str(file))
    
    actual_sample_size = min(sample_size, len(filtered_images))
    selected_images = random.sample(filtered_images, actual_sample_size)
    return selected_images
    

#download_filtered_images_locally(combine_images(image_folder), 'package_images')

# %%
### Put images under one dir 
def get_jpeg_images(folder: str) -> list[Path]:
    return [f for f in Path(folder).iterdir() if f.suffix.lower() == '.jpeg']


def clean_image_name(filename: str) -> str:
    # "1_jpg.rf.abc123.jpg" -> split on first "jpg" -> "1_" -> "1_.jpeg"
    base = filename.split('jpg')[0]  # "1_"
    return base + 'jpeg'


def copy_to_cleaned(images: list[Path], output_dir: Path) -> None:
    output_dir.mkdir(parents=True, exist_ok=True)

    for src in images:
        new_name = clean_image_name(src.name)
        dest = output_dir / new_name
        shutil.copy2(src, dest)
        print(f'Copied: {src.name} -> {new_name}')


def process_images(package_images_dir: str) -> None:
    folder = Path(package_images_dir)
    cleaned_dir = folder / 'cleaned_images'

    images = get_jpeg_images(str(folder))
    print(f'Found {len(images)} JPEG images')

    copy_to_cleaned(images, cleaned_dir)
    print(f'Done. Cleaned images saved to: {cleaned_dir}')


#process_images('package_images')

# %%
os.listdir(os.path.join(os.getcwd(), 'package_images/cleaned_images'))[:10]
# Out:
# ['img-5741-_jpg.rf.c559b7fe8e0f70b42e798310df68f934.jpg',
#  'img-77-_jpg.rf.d1328deaea0b17ae5ab1e906ae8ed5fb.jpg',
#  'img-5008-_jpg.rf.489c4630cb08598f31ebf0cdb9e10ed8.jpg',
#  'img-5045-_jpg.rf.7e502d392b3ba7bf342e434b6361b77d.jpg',
#  'img-482-_jpg.rf.e2d454b9b7175a5630007437d298195d.jpg',
#  'img-859-_jpg.rf.d9fbe9a675a9eeb9e889d9381263b53b.jpg',
#  'img-3171-_jpg.rf.b81522a1c889dfdbecfef7e28d7c8068.jpg',
#  'img-6515-_jpg.rf.39fa3e6554d4a4fa2a3e97f7d3837b43.jpg',
#  'img-6589-_jpg.rf.a7a5b75cd2ef53bac8ecde0eb819a15a.jpg',
#  'img-2377-_jpg.rf.2e0e0054d8a0038f134abed376bd82a3.jpg']

# %%
output_dir = Path(os.path.join(os.getcwd(), 'package_images/cleaned_images'))

def clean_image_name(image_name: str, index: int) -> str: 
    base = image_name.split('_')[0]
    return base + f'{index}.jpg'


def rename_images(output_dir: Path): 
    for i, image in enumerate(os.listdir(output_dir)): 
        os.rename(output_dir / image, output_dir / clean_image_name(image, i))

#rename_images(output_dir)

# %%
from PIL import Image 

moose_images = Path(os.path.join(os.getcwd(), 'package_images/moose_images/train'))

def resize_image(transformations: list) -> None: 
    pass 

#rename_images(moose_images)


img = Image.open(os.path.join(moose_images, random.choice((os.listdir(moose_images)))))
width, height = img.size 
width, height
# Out:
# (1333, 800)

# %%
# !mv package_images/moose_images/train moose_images

# %%
# !mv package_images/cleaned_images package_images
# Out:
# mv: package_images/cleaned_images and package_images/cleaned_images are identical

# %%
coyotes_folder = os.path.join(os.getcwd(), 'coyote_images')

print(f'coyotes_folder: {coyotes_folder}')

download_filtered_images_locally(combine_images(coyotes_folder), coyotes_folder)
# Out:
# coyotes_folder: /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/coyote_images

# %%
deer_folder = os.path.join(os.getcwd(), 'package_images/deer_images')

download_filtered_images_locally(combine_images(deer_folder), deer_folder)

# %%
coyotes_folder = Path(os.path.join(os.getcwd(), 'coyote_images'))

for i, image in enumerate(os.listdir(coyotes_folder)): 
    new_image_name = f'{i}_coyote.jpg'
    os.rename(coyotes_folder / image, coyotes_folder / new_image_name)

# %%
deer_folder = Path(os.getcwd(), 'deer_images')
extensions = {'.jpg', '.jpeg', '.png', '.webp'}
index = 0 
for image_type in deer_folder.iterdir(): 
    print(image_type)
    for image in os.listdir(os.path.join(deer_folder, image_type)): 
        if image.endswith(tuple(extensions)): 
            new_image_name = f'{index}_deer.jpg'
            index += 1
            os.rename(deer_folder / image_type / image, deer_folder / new_image_name)
# Out:
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/deer_images/valid
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/deer_images/test
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/deer_images/train

# %%
os.makedirs('image_sizes', exist_ok=True)
cur_dir = os.getcwd()
training_image_folders = [os.path.join(cur_dir, folder) for folder in os.listdir(cur_dir) if folder.endswith('images')]
print(training_image_folders)
# Out:
# ['/Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images', '/Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/coyote_images', '/Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/deer_images', '/Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images']

# %%
from typing import Tuple 
from PIL import Image 
import shutil
from pathlib import Path

# Root folder that contains coyote_images, deer_images, image_sizes, etc.
ROOT = Path(os.getcwd())

# Blank output folder where size-bin folders will be created
OUTPUT_DIR = ROOT / "image_sizes"
OUTPUT_DIR.mkdir(exist_ok=True)

# Image extensions to process
IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".webp"}

# Set this to True if you want to move images instead of copy them
MOVE_FILES = False

for subdir in ROOT.iterdir():
    # Skip files, skip image_sizes itself
    if not subdir.is_dir() or subdir == OUTPUT_DIR:
        continue

    for image_path in subdir.iterdir():
        if not image_path.is_file():
            continue

        if image_path.suffix.lower() not in IMAGE_EXTENSIONS:
            continue

        try:
            with Image.open(image_path) as img:
                width, height = img.size

            # Folder name example: 640x640, 1096x1290, etc.
            size_folder = OUTPUT_DIR / f"{width}x{height}"
            size_folder.mkdir(exist_ok=True)

            # Preserve original class/source folder in the filename
            # Example: coyote_images_img001.jpg
            destination = size_folder / f"{subdir.name}_{image_path.name}"

            if MOVE_FILES:
                shutil.move(str(image_path), str(destination))
            else:
                shutil.copy2(image_path, destination)

            print(f"{image_path} -> {destination}")

        except Exception as e:
            print(f"Skipping {image_path}: {e}")
# Out:
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4815-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4815-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-3283-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-3283-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-3329-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-3329-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/77.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_77.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-7385-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-7385-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4950-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4950-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5992-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5992-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-1482-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-1482-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5584-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5584-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-724-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-724-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/88.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_88.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4842-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4842-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5750-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5750-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-7278-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img
.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-135-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-135-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-2846-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-2846-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-3754-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-3754-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5680-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5680-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5045-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5045-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/package.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_package.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/gp4.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_gp4.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5383-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5383-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5696-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5696-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-6540-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-6540-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-2850-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-2850-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4603-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4603-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-748-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-748-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-1051-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-1051-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-1817-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-1817-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-3579-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-3579-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4195-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4195-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-3650-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-3650-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-3715-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-3715-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-6517-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-6517-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-2554-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-2554-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4879-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4879-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-932-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-932-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-3851-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-3851-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-2256-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-2256-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-7054-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-7054-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5069-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5069-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-3914-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-3914-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-949-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-949-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-2190-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-2190-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4044-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4044-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4290-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4290-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5897-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5897-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-3040-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-3040-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-6184-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-6184-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-158-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-158-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-7150-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-7150-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-1987-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-1987-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5497-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5497-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-637-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-637-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-2997-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-2997-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-6038-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-6038-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4681-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4681-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-5993-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-5993-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-2240-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-2240-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-6203-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-6203-.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/package_images/img-4547-.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/640x640/package_images_img-4547-.jpg
# ...
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img922.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img922.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img936.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img936.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img249.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img249.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img507.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img507.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img261.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img261.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img275.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img275.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img513.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img513.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img329.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img329.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img473.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img473.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img315.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img315.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img301.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img301.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img467.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img467.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img38.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img38.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img498.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img498.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img10.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img10.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img895.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img895.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img659.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img659.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img881.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img881.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img117.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img117.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img671.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img671.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img665.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img665.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img103.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img103.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img856.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img856.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img842.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img842.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img868.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img868.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img854.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img854.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img698.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img698.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img840.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img840.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img673.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img673.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img115.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img115.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img101.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img101.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img667.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img667.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img897.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img897.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img129.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img129.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img883.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img883.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img12.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img12.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img317.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img317.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img471.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img471.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img465.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img465.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img303.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img303.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img459.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img459.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img288.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img288.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img263.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img263.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img505.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img505.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img511.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img511.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img277.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img277.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img539.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img539.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img908.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img908.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img920.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img920.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img934.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img934.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img707.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img707.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img713.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img713.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img712.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img712.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img706.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img706.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img935.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img935.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img921.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img921.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img909.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img909.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img538.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img538.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img510.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img510.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img276.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img276.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img262.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img262.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img504.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img504.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img289.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img289.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img458.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img458.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img464.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img464.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img302.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img302.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img316.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img316.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img470.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img470.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img13.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img13.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img882.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img882.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img896.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img896.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img128.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img128.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img100.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img100.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img666.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img666.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img672.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img672.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img114.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img114.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img841.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img841.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img699.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img699.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img855.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img855.jpg
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/moose_images/img869.jpg -> /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training/image_sizes/1333x800/moose_images_img869.jpg

# %%
from asyncio.tasks import all_tasks


def total_image_count(ROOT_DIR) -> int: 
    print(f'{ROOT_DIR}')
    all_images = []
    for image_folder in os.listdir(ROOT_DIR): 
        if image_folder.endswith('_images'): 
            image_folder_path = os.path.join(ROOT_DIR, image_folder)
            images = os.listdir(os.path.join(os.getcwd(), image_folder_path))
            print(f'Length of images in dataset {image_folder}: {len(images)})')
            for image in images: 
                all_images.append(image)
    return len(all_images)

total_images = total_image_count(ROOT_DIR = os.getcwd())
print(f'total images in training dataset: {total_images}')
# Out:
# /Users/sv/Desktop/Desktop - S’s MacBook Pro/link/model_training
# Length of images in dataset package_images: 875)
# Length of images in dataset coyote_images: 628)
# Length of images in dataset deer_images: 3550)
# Length of images in dataset moose_images: 1002)
# total images in training dataset: 6055

# %% [markdown]
# More package images are needed. Deer images are too overrepresented. Moose and coyote images are fine, but there may
# be detection issues between coyote and dogs (already built into yolo). More images are needed of coyotes to differentiate between the two.
